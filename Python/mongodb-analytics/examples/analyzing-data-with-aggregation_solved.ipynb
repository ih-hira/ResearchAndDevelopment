# %%
import pymongo
import pprint

# %%
client = pymongo.MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
trips = client.citibike.trips

# %%
# Replace XXXX with your aggregation pipeline to answer the question:
# Citibike trips that start at station id 279 end most frequently at what station id?
pipeline = [
    {
        '$group':
            {
                '_id': {
                    'start station id': '$start station id',
                    'end station id': '$end station id'

                },
                'count': {'$sum': 1}

            }

    },
    {
        '$match':{'_id.start station id':279}
    },
    {
        '$sort': {'count': -1}
    }

]

# %%
# print the results
for trip in trips.aggregate(pipeline):
    pprint.pprint(trip)
# Out:
# {'_id': {'end station id': 279, 'start station id': 279}, 'count': 137}
# {'_id': {'end station id': 316, 'start station id': 279}, 'count': 112}
# {'_id': {'end station id': 259, 'start station id': 279}, 'count': 104}
# {'_id': {'end station id': 387, 'start station id': 279}, 'count': 99}
# {'_id': {'end station id': 224, 'start station id': 279}, 'count': 86}
# {'_id': {'end station id': 306, 'start station id': 279}, 'count': 83}
# {'_id': {'end station id': 268, 'start station id': 279}, 'count': 80}
# {'_id': {'end station id': 260, 'start station id': 279}, 'count': 75}
# {'_id': {'end station id': 308, 'start station id': 279}, 'count': 73}
# {'_id': {'end station id': 360, 'start station id': 279}, 'count': 71}
# {'_id': {'end station id': 3002, 'start station id': 279}, 'count': 63}
# {'_id': {'end station id': 361, 'start station id': 279}, 'count': 57}
# {'_id': {'end station id': 337, 'start station id': 279}, 'count': 56}
# {'_id': {'end station id': 487, 'start station id': 279}, 'count': 55}
# {'_id': {'end station id': 2009, 'start station id': 279}, 'count': 54}
# {'_id': {'end station id': 401, 'start station id': 279}, 'count': 53}
# {'_id': {'end station id': 307, 'start station id': 279}, 'count': 52}
# {'_id': {'end station id': 376, 'start station id': 279}, 'count': 51}
# {'_id': {'end station id': 502, 'start station id': 279}, 'count': 51}
# {'_id': {'end station id': 304, 'start station id': 279}, 'count': 50}
# {'_id': {'end station id': 501, 'start station id': 279}, 'count': 47}
# {'_id': {'end station id': 332, 'start station id': 279}, 'count': 46}
# {'_id': {'end station id': 2010, 'start station id': 279}, 'count': 43}
# {'_id': {'end station id': 232, 'start station id': 279}, 'count': 43}
# {'_id': {'end station id': 174, 'start station id': 279}, 'count': 41}
# {'_id': {'end station id': 291, 'start station id': 279}, 'count': 39}
# {'_id': {'end station id': 408, 'start station id': 279}, 'count': 38}
# {'_id': {'end station id': 329, 'start station id': 279}, 'count': 37}
# {'_id': {'end station id': 195, 'start station id': 279}, 'count': 37}
# {'_id': {'end station id': 511, 'start station id': 279}, 'count': 36}
# {'_id': {'end station id': 319, 'start station id': 279}, 'count': 34}
# {'_id': {'end station id': 415, 'start station id': 279}, 'count': 34}
# {'_id': {'end station id': 264, 'start station id': 279}, 'count': 33}
# {'_id': {'end station id': 350, 'start station id': 279}, 'count': 33}
# {'_id': {'end station id': 312, 'start station id': 279}, 'count': 32}
# {'_id': {'end station id': 531, 'start station id': 279}, 'count': 32}
# {'_id': {'end station id': 147, 'start station id': 279}, 'count': 31}
# {'_id': {'end station id': 151, 'start station id': 279}, 'count': 30}
# {'_id': {'end station id': 386, 'start station id': 279}, 'count': 30}
# {'_id': {'end station id': 327, 'start station id': 279}, 'count': 30}
# {'_id': {'end station id': 341, 'start station id': 279}, 'count': 29}
# {'_id': {'end station id': 426, 'start station id': 279}, 'count': 29}
# {'_id': {'end station id': 445, 'start station id': 279}, 'count': 27}
# {'_id': {'end station id': 152, 'start station id': 279}, 'count': 26}
# {'_id': {'end station id': 150, 'start station id': 279}, 'count': 26}
# {'_id': {'end station id': 320, 'start station id': 279}, 'count': 26}
# {'_id': {'end station id': 410, 'start station id': 279}, 'count': 25}
# {'_id': {'end station id': 394, 'start station id': 279}, 'count': 25}
# {'_id': {'end station id': 321, 'start station id': 279}, 'count': 24}
# {'_id': {'end station id': 428, 'start station id': 279}, 'count': 24}
# {'_id': {'end station id': 476, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 534, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 351, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 257, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 433, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 249, 'start station id': 279}, 'count': 23}
# {'_id': {'end station id': 485, 'start station id': 279}, 'count': 22}
# {'_id': {'end station id': 315, 'start station id': 279}, 'count': 22}
# {'_id': {'end station id': 263, 'start station id': 279}, 'count': 22}
# {'_id': {'end station id': 276, 'start station id': 279}, 'count': 22}
# {'_id': {'end station id': 417, 'start station id': 279}, 'count': 22}
# {'_id': {'end station id': 427, 'start station id': 279}, 'count': 21}
# {'_id': {'end station id': 295, 'start station id': 279}, 'count': 21}
# {'_id': {'end station id': 504, 'start station id': 279}, 'count': 21}
# {'_id': {'end station id': 545, 'start station id': 279}, 'count': 21}
# {'_id': {'end station id': 432, 'start station id': 279}, 'count': 20}
# {'_id': {'end station id': 217, 'start station id': 279}, 'count': 20}
# {'_id': {'end station id': 296, 'start station id': 279}, 'count': 20}
# {'_id': {'end station id': 455, 'start station id': 279}, 'count': 20}
# {'_id': {'end station id': 392, 'start station id': 279}, 'count': 20}
# {'_id': {'end station id': 461, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 356, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 2008, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 532, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 507, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 301, 'start station id': 279}, 'count': 19}
# {'_id': {'end station id': 340, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 411, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 524, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 303, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 3119, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 355, 'start station id': 279}, 'count': 18}
# {'_id': {'end station id': 519, 'start station id': 279}, 'count': 17}
# {'_id': {'end station id': 317, 'start station id': 279}, 'count': 17}
# {'_id': {'end station id': 339, 'start station id': 279}, 'count': 17}
# {'_id': {'end station id': 309, 'start station id': 279}, 'count': 16}
# {'_id': {'end station id': 82, 'start station id': 279}, 'count': 16}
# {'_id': {'end station id': 297, 'start station id': 279}, 'count': 16}
# {'_id': {'end station id': 79, 'start station id': 279}, 'count': 16}
# {'_id': {'end station id': 229, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 516, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 393, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 331, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 293, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 363, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 460, 'start station id': 279}, 'count': 15}
# {'_id': {'end station id': 2004, 'start station id': 279}, 'count': 14}
# {'_id': {'end station id': 330, 'start station id': 279}, 'count': 14}
# {'_id': {'end station id': 349, 'start station id': 279}, 'count': 13}
# {'_id': {'end station id': 438, 'start station id': 279}, 'count': 13}
# {'_id': {'end station id': 285, 'start station id': 279}, 'count': 13}
# {'_id': {'end station id': 322, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 250, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 265, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 146, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 302, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 518, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 472, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 473, 'start station id': 279}, 'count': 12}
# {'_id': {'end station id': 382, 'start station id': 279}, 'count': 11}
# {'_id': {'end station id': 412, 'start station id': 279}, 'count': 11}
# {'_id': {'end station id': 2012, 'start station id': 279}, 'count': 11}
# {'_id': {'end station id': 375, 'start station id': 279}, 'count': 11}
# {'_id': {'end station id': 237, 'start station id': 279}, 'count': 10}
# {'_id': {'end station id': 527, 'start station id': 279}, 'count': 10}
# {'_id': {'end station id': 497, 'start station id': 279}, 'count': 10}
# {'_id': {'end station id': 2003, 'start station id': 279}, 'count': 10}
# {'_id': {'end station id': 400, 'start station id': 279}, 'count': 10}
# {'_id': {'end station id': 347, 'start station id': 279}, 'count': 9}
# {'_id': {'end station id': 348, 'start station id': 279}, 'count': 9}
# {'_id': {'end station id': 280, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 3104, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 377, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 236, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 459, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 323, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 128, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 326, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 475, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 251, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 161, 'start station id': 279}, 'count': 8}
# {'_id': {'end station id': 405, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 328, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 311, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 167, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 278, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 493, 'start station id': 279}, 'count': 7}
# {'_id': {'end station id': 225, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 430, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 440, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 414, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 83, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 407, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 439, 'start station id': 279}, 'count': 6}
# {'_id': {'end station id': 346, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 160, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 3074, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 402, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 168, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 468, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 266, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 368, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 153, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 253, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 483, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 491, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 247, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 539, 'start station id': 279}, 'count': 5}
# {'_id': {'end station id': 540, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 358, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 406, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 3058, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 462, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 380, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 525, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 528, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 127, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 2000, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 383, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 469, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 467, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 536, 'start station id': 279}, 'count': 4}
# {'_id': {'end station id': 3105, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 453, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 486, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 523, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 454, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 403, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 444, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 3142, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 238, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 3093, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 336, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 391, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 494, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 310, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 3055, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 116, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 435, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 284, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 521, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 481, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 216, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 248, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 2022, 'start station id': 279}, 'count': 3}
# {'_id': {'end station id': 2002, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 384, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 465, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 514, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 389, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3242, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 416, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3064, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3148, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3159, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 526, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3016, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 274, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 252, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 503, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 470, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3147, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 517, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3135, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 212, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 546, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3173, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 537, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 369, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 482, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3103, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3140, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 496, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 508, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 357, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 474, 'start station id': 279}, 'count': 2}
# {'_id': {'end station id': 3229, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3052, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 480, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 456, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3154, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 515, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 281, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 335, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 223, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3158, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3222, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 484, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3155, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 449, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 262, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 342, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3224, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 385, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 300, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 254, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 463, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3144, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3141, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3122, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 533, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3171, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 298, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 373, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 420, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 239, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3166, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 359, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3237, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3223, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 436, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 243, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3244, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3059, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3088, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 275, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3113, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 492, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 245, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 282, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 434, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 325, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 2006, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 242, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 244, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 3017, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 522, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 509, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 379, 'start station id': 279}, 'count': 1}
# {'_id': {'end station id': 458, 'start station id': 279}, 'count': 1}
